# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("merged_datasets.csv")
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_3840\228374165.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("merged_datasets.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33703 entries, 0 to 33702
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   index                                  33703 non-null  int64
#  1   area                                   33703 non-null  float64
#  2   building_type                          33703 non-null  object
#  3   building_nature                        33703 non-null  object
#  4   image_url                              17265 non-null  object
#  5   num_bath_rooms                         33703 non-null  float64
#  6   num_bed_rooms                          33703 non-null  float64
#  7   price                                  33703 non-null  float64
#  8   property_description                   19029 non-null  object
#  9   property_overview                      18509 non-null  object
#  10  property_url                           33679 non-null  object
#  11  purpose                                33703 non-null  object
#  12  city                                   33703 non-null  object
#  13  locality                               33703 non-null  object
#  14  address                                28526 non-null  object
#  15  id                                     33703 non-null  object
#  16  garage                                 33703 non-null  float64
#  17  relaxation_amenity_count               33703 non-null  int64
#  18  security_amenity_count                 33703 non-null  int64
#  19  maintenance_or_cleaning_amenity_count  33703 non-null  int64
#  20  social_amenity_count                   33703 non-null  int64
#  21  expendable_amenity_count               33703 non-null  int64
#  22  service_staff_amenity_count            33703 non-null  int64
#  23  unclassify_amenity_count               33703 non-null  int64
# dtypes: float64(5), int64(8), object(11)
# memory usage: 6.2+ MB

# %%
data["building_type"].unique()
# Out:
# array(['Apartment', 'Shop', 'Floor', 'Office', 'Building', 'Plot',
#        'Duplex', 'Warehouse', 'Factory', 'Apartment/Flats',
#        'Office space', 'Duplex Home', 'Showroom / Shop / Restaurant',
#        'Independent House', 'House', 'Commerical - Other',
#        'Apartment, Commercial', 'Showroom/Shop/Restaurant',
#        'Office Space', 'Residential Plot', 'Industrial Space',
#        'Commercial Plot', 'Land Sharing Flat', 'Sublet/Room'],
#       dtype=object)

# %%
data["building_type"].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='building_type'>

# %%
len(data[data["building_type"].str.contains("Apartment")].building_type.index) ,len(data[data["building_type"] =="Apartment"].building_type.index)
# Out:
# (26942, 26524)

# %%
data["building_type"].value_counts()
# Out:
# building_type
# Apartment                       26524
# Office                           2210
# Building                         1412
# Shop                              946
# Floor                             880
# Plot                              791
# Apartment/Flats                   416
# House                             172
# Residential Plot                  133
# Duplex                             77
# Office space                       41
# Warehouse                          29
# Factory                            19
# Office Space                       15
# Showroom/Shop/Restaurant            8
# Duplex Home                         7
# Commercial Plot                     5
# Commerical - Other                  4
# Land Sharing Flat                   4
# Independent House                   3
# Showroom / Shop / Restaurant        2
# Industrial Space                    2
# Apartment, Commercial               2
# Sublet/Room                         1
# Name: count, dtype: int64

# %%
data["new_building_type"] = data["building_type"]

# %%
data["new_building_type"].value_counts()
# Out:
# new_building_type
# Apartment                       26524
# Office                           2210
# Building                         1412
# Shop                              946
# Floor                             880
# Plot                              791
# Apartment/Flats                   416
# House                             172
# Residential Plot                  133
# Duplex                             77
# Office space                       41
# Warehouse                          29
# Factory                            19
# Office Space                       15
# Showroom/Shop/Restaurant            8
# Duplex Home                         7
# Commercial Plot                     5
# Commerical - Other                  4
# Land Sharing Flat                   4
# Independent House                   3
# Showroom / Shop / Restaurant        2
# Industrial Space                    2
# Apartment, Commercial               2
# Sublet/Room                         1
# Name: count, dtype: int64

# %%
apat_vals = data[data["building_type"].str.contains("Apartment")].building_type
office_vals = data[data["building_type"].str.contains("Office")].building_type
shop_vals = data[data["building_type"].str.contains("Shop")].building_type
plot_vals = data[data["building_type"].str.contains("Plot")].building_type
commercial_vals = data[data["building_type"].str.contains("Commercial")].building_type
house_vals = data[data["building_type"].str.contains("House")].building_type
duplex_vals = data[data["building_type"].str.contains("Duplex")].building_type


    

data["new_building_type"].replace(set(apat_vals),value = "Apartment",inplace = True)
data["new_building_type"].replace(set(office_vals),value = "Office",inplace = True)
data["new_building_type"].replace(set(shop_vals),value = "Shop",inplace = True)
data["new_building_type"].replace(set(plot_vals),value = "Plot",inplace = True)
data["new_building_type"].replace(set(commercial_vals),value = "Commercial",inplace = True)
data["new_building_type"].replace(set(house_vals),value = "House",inplace = True)
data["new_building_type"].replace(set(duplex_vals),value = "Duplex",inplace = True)

# %%
data["new_building_type"].unique()
# Out:
# array(['Apartment', 'Shop', 'Floor', 'Office', 'Building', 'Plot',
#        'Duplex', 'Warehouse', 'Factory', 'House', 'Commerical - Other',
#        'Industrial Space', 'Land Sharing Flat', 'Sublet/Room'],
#       dtype=object)

# %%
data["new_building_type"].value_counts()
# Out:
# new_building_type
# Apartment             26942
# Office                 2266
# Building               1412
# Shop                    956
# Plot                    929
# Floor                   880
# House                   175
# Duplex                   84
# Warehouse                29
# Factory                  19
# Commerical - Other        4
# Land Sharing Flat         4
# Industrial Space          2
# Sublet/Room               1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    index    area building_type building_nature
# 0      0  1185.0     Apartment     Residential  \
# 1      1  2464.0     Apartment     Residential
# 2      2  1140.0     Apartment     Residential
# 3      3  1920.0     Apartment     Residential
# 4      4  1445.0     Apartment     Residential
#
#                                            image_url  num_bath_rooms
# 0  https://images-cdn.bproperty.com/thumbnails/15...             0.0  \
# 1  https://images-cdn.bproperty.com/thumbnails/15...             4.0
# 2  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 3  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 4  https://images-cdn.bproperty.com/thumbnails/15...             3.0
#
#    num_bed_rooms       price
# 0            3.0   6100000.0  \
# 1            3.0  28900000.0
# 2            3.0   7500000.0
# 3            3.0  20000000.0
# 4            3.0  10800000.0
#
#                                 property_description
# 0  Grab This 1185 Sq Ft Beautiful Flat Is Vacant ...  \
# 1  A Vibrant 2464 Sq Ft Residential Flat For Sale...
# 2  1140 Sq Ft Nicely Planned Apartment Is Availab...
# 3  A Modern Well-planned Apartment Of 1920 Sq Ft ...
# 4  1445 Sq Ft Ready Flat For Sale In Banasree, Wi...
#
#                                    property_overview  ...           id garage
# 0  This flat consists of facilities you can think...  ...  bproperty-0    0.0  \
# 1  Ready to move in somewhere with everything nea...  ...  bproperty-1    0.0
# 2  A spacious 1140  Square Feet apartment in Mirp...  ...  bproperty-2    0.0
# 3  Looking for the perfect home that offers a lux...  ...  bproperty-3    0.0
# 4  Choosing a new home can be an overwhelming exp...  ...  bproperty-4    0.0
#
#   relaxation_amenity_count security_amenity_count
# 0                        0                      1  \
# 1                        0                      2
# 2                        0                      2
# 3                        0                      1
# 4                        0                      0
#
#   maintenance_or_cleaning_amenity_count social_amenity_count
# 0                                     2                    0  \
# 1                                     0                    0
# 2                                     2                    0
# 3                                     2                    0
# 4                                     2                    0
#
#    expendable_amenity_count  service_staff_amenity_count
# 0                         2                            0  \
# 1                         3                            0
# 2                         2                            0
# 3                         3                            0
# 4                         1                            0
#
#    unclassify_amenity_count  new_building_type
# 0                         3          Apartment
# 1                         4          Apartment
# 2                         4          Apartment
# 3                         3          Apartment
# 4                         4          Apartment
#
# [5 rows x 25 columns]

# %%
new_building_type  = data.groupby("new_building_type")["new_building_type"].agg("count")

# %%
building_type_less_100 = new_building_type[new_building_type < 100]

# %%
data["new_building_type"] = data["new_building_type"].apply(lambda i:"Other" if i in building_type_less_100 else i)

# %%
data["new_building_type"].value_counts()
# Out:
# new_building_type
# Apartment    26942
# Office        2266
# Building      1412
# Shop           956
# Plot           929
# Floor          880
# House          175
# Other          143
# Name: count, dtype: int64

# %%
percentage_building_type = (data["new_building_type"].value_counts()/ data["new_building_type"].value_counts().sum())*100
plt.subplots(figsize=(10, 5))
percentage_building_type.plot.barh()
plt.title("Percentage of properties over differnt Building Type")
plt.xlabel("percentage")
plt.show()

# %%
temp = pd.Series(np.where(data["price"]  <= 0,"missing price","price present"))
prct = (temp.value_counts()/temp.value_counts().sum())*100

prct.plot(kind = "barh")
# Out:
# <Axes: >

# %%
missing_price = data.loc[data['price'] <= 0, 'price']
print(missing_price)
# Out:
# 17603    0.0
# 32073    0.0
# 32177    0.0
# 32332    0.0
# 32347    0.0
#         ...
# 33633    0.0
# 33635    0.0
# 33642    0.0
# 33655    0.0
# 33656    0.0
# Name: price, Length: 479, dtype: float64

# %%
data = data[data['price'] != 0]
data
# Out:
#        index     area building_type building_nature
# 0          0   1185.0     Apartment     Residential  \
# 1          1   2464.0     Apartment     Residential
# 2          2   1140.0     Apartment     Residential
# 3          3   1920.0     Apartment     Residential
# 4          4   1445.0     Apartment     Residential
# ...      ...      ...           ...             ...
# 33698  39113   8000.0        Office      Commercial
# 33699  39115  10000.0        Office      Commercial
# 33700  39116   5000.0        Office      Commercial
# 33701  39143  10000.0        Office      Commercial
# 33702  39161   5000.0        Office      Commercial
#
#                                                image_url  num_bath_rooms
# 0      https://images-cdn.bproperty.com/thumbnails/15...             0.0  \
# 1      https://images-cdn.bproperty.com/thumbnails/15...             4.0
# 2      https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 3      https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 4      https://images-cdn.bproperty.com/thumbnails/15...             3.0
# ...                                                  ...             ...
# 33698                                                NaN             0.0
# 33699                                                NaN             0.0
# 33700                                                NaN             0.0
# 33701                                                NaN             0.0
# 33702                                                NaN             0.0
#
#        num_bed_rooms       price
# 0                3.0   6100000.0  \
# 1                3.0  28900000.0
# 2                3.0   7500000.0
# 3                3.0  20000000.0
# 4                3.0  10800000.0
# ...              ...         ...
# 33698            0.0       110.0
# 33699            0.0       100.0
# 33700            0.0       120.0
# 33701            0.0       120.0
# 33702            0.0        70.0
#
#                                     property_description
# 0      Grab This 1185 Sq Ft Beautiful Flat Is Vacant ...  \
# 1      A Vibrant 2464 Sq Ft Residential Flat For Sale...
# 2      1140 Sq Ft Nicely Planned Apartment Is Availab...
# 3      A Modern Well-planned Apartment Of 1920 Sq Ft ...
# 4      1445 Sq Ft Ready Flat For Sale In Banasree, Wi...
# ...                                                  ...
# 33698                        bd Office Rent Uttara Dhaka
# 33699                    10000 sqf office rent at Uttara
# 33700                 commercial space for rent in dhaka
# 33701                   Commercial Space Rent at Tejgaon
# 33702             Commercial Office Rent Mohakhali Dhaka
#
#                                        property_overview  ...           id
# 0      This flat consists of facilities you can think...  ...  bproperty-0  \
# 1      Ready to move in somewhere with everything nea...  ...  bproperty-1
# 2      A spacious 1140  Square Feet apartment in Mirp...  ...  bproperty-2
# 3      Looking for the perfect home that offers a lux...  ...  bproperty-3
# 4      Choosing a new home can be an overwhelming exp...  ...  bproperty-4
# ...                                                  ...  ...          ...
# 33698         Commercial Building for office rent Uttara  ...   sharif-233
# 33699                    10000 sqf office rent at Uttara  ...   sharif-235
# 33700                 commercial space for rent in dhaka  ...   sharif-236
# 33701                   Commercial Space Rent at Tejgaon  ...   sharif-263
# 33702                 Commercial space rent at Mohakhali  ...   sharif-281
#
#       garage relaxation_amenity_count security_amenity_count
# 0        0.0                        0                      1  \
# 1        0.0                        0                      2
# 2        0.0                        0                      2
# 3        0.0                        0                      1
# 4        0.0                        0                      0
# ...      ...                      ...                    ...
# 33698    0.0                        0                      0
# 33699    0.0                        0                      0
# 33700    0.0                        0                      0
# 33701    0.0                        0                      0
# 33702    0.0                        0                      0
#
#       maintenance_or_cleaning_amenity_count social_amenity_count
# 0                                         2                    0  \
# 1                                         0                    0
# 2                                         2                    0
# 3                                         2                    0
# 4                                         2                    0
# ...                                     ...                  ...
# 33698                                     0                    0
# 33699                                     0                    0
# 33700                                     0                    0
# 33701                                     0                    0
# 33702                                     0                    0
#
#        expendable_amenity_count  service_staff_amenity_count
# 0                             2                            0  \
# 1                             3                            0
# 2                             2                            0
# 3                             3                            0
# 4                             1                            0
# ...                         ...                          ...
# 33698                         0                            0
# 33699                         0                            0
# 33700                         0                            0
# 33701                         0                            0
# 33702                         0                            0
#
#        unclassify_amenity_count  new_building_type
# 0                             3          Apartment
# 1                             4          Apartment
# 2                             4          Apartment
# 3                             3          Apartment
# 4                             4          Apartment
# ...                         ...                ...
# 33698                         0             Office
# 33699                         0             Office
# 33700                         0             Office
# 33701                         0             Office
# 33702                         0             Office
#
# [33224 rows x 25 columns]

# %%
missing_price = data.loc[data['price'] <= 0, 'price']
print(missing_price)
# Out:
# Series([], Name: price, dtype: float64)

# %%
temp = pd.Series(np.where(data["price"]  <= 0,"missing price","price present"))
prct = (temp.value_counts()/temp.value_counts().sum())*100

prct.plot(kind = "barh")
# Out:
# <Axes: >

# %%
z_score_price = data["price"]
mean = np.mean(z_score_price)
std_dev = np.std(z_score_price)
z_scores = (z_score_price - mean) / std_dev
print(z_scores)
# Out:
# 0       -0.008133
# 1       -0.007961
# 2       -0.008122
# 3       -0.008028
# 4       -0.008097
#            ...
# 33698   -0.008179
# 33699   -0.008179
# 33700   -0.008179
# 33701   -0.008179
# 33702   -0.008179
# Name: price, Length: 33224, dtype: float64

# %%
for i in z_scores:
    if i > 3 and i <-3:
        print(i)
    else:
        print("No Outliers")
    break
# Out:
# No Outliers

# %%
avg_price  = data.groupby("new_building_type")["price"].agg("median")
avg_price
# Out:
# new_building_type
# Apartment     115000.0
# Building      275750.0
# Floor         327000.0
# House         350000.0
# Office        168000.0
# Other         250000.0
# Plot         6500000.0
# Shop          235500.0
# Name: price, dtype: float64
